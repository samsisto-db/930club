# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import urllib
import urllib2
import json
from googleapiclient.discovery import build
import pprint
import time

pd.set_option('display.max_colwidth', -1)

# %%
file = '/Users/samsisto/Desktop/930club/930shows2016.html'

# %%
f = open(file)
contents = f.read()
soup = BeautifulSoup(contents, "html.parser")

# %%
soup.find("button", {'data-posttitle':True})['data-posttitle']
# Out:
# u'Majid Jordan at 9:30 Club'

# %%
button_data = soup.find_all("button", {'data-posttitle':True})

show_name = []
date_of_show = []

for item in button_data:
    show_name.append(item['data-posttitle'])
    date_of_show.append(item['data-dateyyyymmdd'])

showinfo = pd.DataFrame({'Show_name' : show_name,'Date' : date_of_show})
showinfo['Show_name'] = showinfo['Show_name'].map(lambda x: x.rstrip(' at 9:30 Club'))

# %%
my_api_key = "AIzaSyDUOr-M7f9WzDNpzEk4uavc802oGIW_b7M"
my_cse_id = "006130872013738183915:ka5nz0sucaa"

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search(
    'majid jordan 930 club', my_api_key, my_cse_id, num=1)
for result in results:
    print result['formattedUrl']
# Out:
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "dailyLimitExceeded"
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-23-b0ca2da81bb7> in <module>()
#       8
#       9 results = google_search(
# ---> 10     'majid jordan 930 club', my_api_key, my_cse_id, num=1)
#      11 for result in results:
#      12     print result['formattedUrl']
#
# <ipython-input-23-b0ca2da81bb7> in google_search(search_term, api_key, cse_id, **kwargs)
#       4 def google_search(search_term, api_key, cse_id, **kwargs):
#       5     service = build("customsearch", "v1", developerKey=api_key)
# ----> 6     res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
#       7     return res['items']
#       8
#
# /Users/samsisto/anaconda/lib/python2.7/site-packages/oauth2client/util.pyc in positional_wrapper(*args, **kwargs)
#     135                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     136                     logger.warning(message)
# --> 137             return wrapped(*args, **kwargs)
#     138         return positional_wrapper
#     139
#
# /Users/samsisto/anaconda/lib/python2.7/site-packages/googleapiclient/http.pyc in execute(self, http, num_retries)
#     836       callback(resp)
#     837     if resp.status >= 300:
# --> 838       raise HttpError(resp, content, uri=self.uri)
#     839     return self.postproc(resp, content)
#     840
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/customsearch/v1?q=majid+jordan+930+club&alt=json&cx=006130872013738183915%3Aka5nz0sucaa&num=1&key=AIzaSyDUOr-M7f9WzDNpzEk4uavc802oGIW_b7M returned "This API requires billing to be enabled on the project. Visit https://console.developers.google.com/billing?project=453701825565 to enable billing.">

# %%
urls=[]

#limit of 100 requests per day
#display link = www.930.com?

for show in show_name:
    time.sleep(5)
    results = google_search(show, my_api_key, my_cse_id, num=1)
    for result in results:
        urls.append(result['formattedUrl'])

showinfo['urls']=urls
# Out:
# Majid Jordan at 9:30 Club
# www.930.com/event/1227877-majid-jordan-washington/
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "dailyLimitExceeded"
# Gang Of Four at 9:30 Club
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-22-8cffd443d1aa> in <module>()
#       3 for show in show_name:
#       4     print show
# ----> 5     results = google_search(show, my_api_key, my_cse_id, num=1)
#       6     for result in results:
#       7         print result['formattedUrl']
#
# <ipython-input-6-b0ca2da81bb7> in google_search(search_term, api_key, cse_id, **kwargs)
#       4 def google_search(search_term, api_key, cse_id, **kwargs):
#       5     service = build("customsearch", "v1", developerKey=api_key)
# ----> 6     res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
#       7     return res['items']
#       8
#
# /Users/samsisto/anaconda/lib/python2.7/site-packages/oauth2client/util.pyc in positional_wrapper(*args, **kwargs)
#     135                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     136                     logger.warning(message)
# --> 137             return wrapped(*args, **kwargs)
#     138         return positional_wrapper
#     139
#
# /Users/samsisto/anaconda/lib/python2.7/site-packages/googleapiclient/http.pyc in execute(self, http, num_retries)
#     836       callback(resp)
#     837     if resp.status >= 300:
# --> 838       raise HttpError(resp, content, uri=self.uri)
#     839     return self.postproc(resp, content)
#     840
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/customsearch/v1?q=Gang+Of+Four+at+9%3A30+Club&alt=json&cx=006130872013738183915%3Aka5nz0sucaa&num=1&key=AIzaSyDUOr-M7f9WzDNpzEk4uavc802oGIW_b7M returned "This API requires billing to be enabled on the project. Visit https://console.developers.google.com/billing?project=453701825565 to enable billing.">

# %%
showinfo['urls']=urls

# %%
showinfo
# Out:
#          Date                       Show_name  \
# 0    20161009  Majid Jordan
# 1    20161008  Gang Of Four
# 2    20161007  Classixx
# 3    20161006  The Temper Trap
# 4    20161005  Taking Back Sunday
# 5    20161004  Warpain
# 6    20161003  Green Day
# 7    20161002  Bastille
# 8    20161001  The Growlers
# 9    20160930  Kaleo
# 10   20160929  Bob Moses
# 11   20160928  Buzzcocks
# 12   20160927  Yun
# 13   20160923  Blind Pilo
# 14   20160921  Lush
# 15   20160919  Okkervil River
# 16   20160918  Built to Spi
# 17   20160916  Cher
# 18   20160915  Angel Olsen
# 19   20160914  Ra Ra Rio
# 20   20160913  Ra Ra Rio
# 21   20160912  Young The Gian
# 22   20160911  Peaches
# 23   20160910  Marian Hi
# 24   20160909  Echo & the Bunnymen
# 25   20160908  Dinosaur Jr.
# 26   20160907  Of Montre
# 27   20160906  Television
# 28   20160904  Diggy Simmons
# 29   20160903  Flume
# ..        ...    ...
# 174  20160219  Anders Osborne
# 175  20160218  The Soul Rebels
# 176  20160217  Unknown Mortal Orchestr
# 177  20160216  Best Coas
# 178  20160214  The Devil Makes Three
# 179  20160213  The Devil Makes Three
# 180  20160212  Graveyard
# 181  20160211  Big Head Todd and The Monsters
# 182  20160210  Joe Russo’s Almost Dead
# 183  20160207  Lupe Fiasco
# 184  20160206  Greensky Bluegrass
# 185  20160205  Greensky Bluegrass
# 186  20160204  Greensky Bluegrass
# 187  20160203  Destructo
# 188  20160130  Lea Delari
# 189  20160129  Super Diamond
# 190  20160128  Josh Abbott Band
# 191  20160127  Jack’s Mannequin
# 192  20160126  Ani DiFranco
# 193  20160125  Halcyon Way
# 194  20160124  Miami Horror
# 195  20160123  Grace Potter
# 196  20160122  Grace Potter
# 197  20160121  Grace Potter
# 198  20160120  Guster
# 199  20160118  Conrad Sewe
# 200  20160116  Cardiknox
# 201  20160115  Lettuce
# 202  20160102  Gogol Bordello
# 203  20160101  Gogol Bordello
#
#                                                    urls
# 0    www.930.com/event/1227877-majid-jordan-washington/
# 1    0
# 2    1
# 3    2
# 4    3
# 5    4
# 6    5
# 7    6
# 8    7
# 9    8
# 10   9
# 11   10
# 12   11
# 13   12
# 14   13
# 15   14
# 16   15
# 17   16
# 18   17
# 19   18
# 20   19
# 21   20
# 22   21
# 23   22
# 24   23
# 25   24
# 26   25
# 27   26
# 28   27
# 29   28
# ..   ..
# 174  173
# 175  174
# 176  175
# 177  176
# 178  177
# 179  178
# 180  179
# 181  180
# 182  181
# 183  182
# 184  183
# 185  184
# 186  185
# 187  186
# 188  187
# 189  188
# 190  189
# 191  190
# 192  191
# 193  192
# 194  193
# 195  194
# 196  195
# 197  196
# 198  197
# 199  198
# 200  199
# 201  200
# 202  201
# 203  202
#
# [204 rows x 3 columns]

# %%
#iloc gives us data from the specified row num (0) and desired column (urls)
x = showinfo.iloc[0]['urls']

#need to append ? to end of the url
x='http://www.930.com/event/1227877-majid-jordan-washington/?'
t='http://www.930.com/event/1255287-taking-back-sunday-washington/'

r = requests.get(x)
b = BeautifulSoup(r.text, 'html.parser')
x = b.find('h3', { "class" : "price-range" })
item = x.nextSibling
if 'class' in item.attrs and 'custom' in item.attrs['class']:
    print 'Sold Out show'
else:
    print 'Not sold out'
# Out:
# Not sold out
